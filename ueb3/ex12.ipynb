# %% [markdown]
# Links zu Dokumentationen/Tutorials für IPython/Python/numpy/matplotlib/git sowie die Sourcodes findet ihr im [GitHub Repo](https://github.com/BerndSchwarzenbacher/numdiff).

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
values = np.loadtxt('ex12_impl_mp.out')
time = values[:,0]
alpha = values[:,1]
alpha_dot = values[:,2]

# %%
plt.plot(time, alpha)
plt.ylabel(r'$\alpha(t)$')
plt.xlabel(r'$t$')
plt.grid()

# %%
plt.plot(time[:200], alpha[:200])
plt.ylabel(r'$\alpha(t)$')
plt.xlabel(r'$t$')
plt.grid()

# %%
q = alpha
p = alpha_dot
H = - np.cos(q) + p**2 / 2

# %% [markdown]
# $H(q(t), p(t))$ ist konstant, weil die Energieerhaltung gelten muss: $\frac{d}{dt} H(p(t),q(t)) = 0$

# %%
plt.plot(H)
plt.ylabel(r'$H(p(t),q(t))$')
plt.xlabel(r'$t$')
plt.axis([0,10000, -1, 0])
plt.grid()

# %%
plt.plot(q, p)
plt.ylabel(r'$p(t)$')
plt.xlabel(r'$q(t)$')
plt.grid()

# %%
values = np.loadtxt('ex12_two_step_gauss.out')
time = values[:,0]
alpha = values[:,1]
alpha_dot = values[:,2]

# %%
plt.plot(time, alpha)
plt.ylabel(r'$\alpha(t)$')
plt.xlabel(r'$t$')
plt.grid()

# %%
plt.plot(time[:200], alpha[:200])
plt.ylabel(r'$\alpha(t)$')
plt.xlabel(r'$t$')
plt.grid()

# %%
q = alpha
p = alpha_dot
H = - np.cos(q) + p**2 / 2

# %%
plt.plot(H)
plt.ylabel(r'$H(p(t),q(t))$')
plt.xlabel(r'$t$')
plt.axis([0,10000, -1, 0])
plt.grid()

# %%
plt.plot(q, p)
plt.ylabel(r'$p(t)$')
plt.xlabel(r'$q(t)$')
plt.grid()
